# %% [markdown]
# <a href="https://colab.research.google.com/github/OliverMaerz/Covid-19/blob/master/Covid-19_Compare_Argentina_curve_to_Italy%2C_Spain_and_Germany.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Reported Covid-19 / Corona Virus Cases - Comparison between Argentina, Italy, Spain, and Germany
#
# Generated with data from Johns Hopkins CSSE: https://github.com/CSSEGISandData
#
# First step is to download the Johns Hopkins CSSE global dataset for confirmed Covid19 cases:

# %%
# !wget -O covid19_confirmed_global.csv https://raw.githubusercontent.com/CSSEGISandData/COVID-19/master/csse_covid_19_data/csse_covid_19_time_series/time_series_covid19_confirmed_global.csv
# !wget -O covid19_deaths_global.csv https://raw.githubusercontent.com/CSSEGISandData/COVID-19/master/csse_covid_19_data/csse_covid_19_time_series/time_series_covid19_deaths_US.csv
# !wget -O covid19_recovered_global.csv https://raw.githubusercontent.com/CSSEGISandData/COVID-19/master/csse_covid_19_data/csse_covid_19_time_series/time_series_covid19_recovered_global.csv
# !ls -al
# Out:
# --2020-04-30 03:31:05--  https://raw.githubusercontent.com/CSSEGISandData/COVID-19/master/csse_covid_19_data/csse_covid_19_time_series/time_series_covid19_confirmed_global.csv
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 151.101.0.133, 151.101.64.133, 151.101.128.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|151.101.0.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 85886 (84K) [text/plain]
# Saving to: ‘covid19_confirmed_global.csv’
#
# covid19_confirmed_g 100%[===================>]  83.87K  --.-KB/s    in 0.03s
#
# 2020-04-30 03:31:05 (3.17 MB/s) - ‘covid19_confirmed_global.csv’ saved [85886/85886]
#
# total 100
# drwxr-xr-x 1 root root  4096 Apr 30 03:31 .
# drwxr-xr-x 1 root root  4096 Apr 30 03:27 ..
# drwxr-xr-x 1 root root  4096 Apr 27 16:13 .config
# -rw-r--r-- 1 root root 85886 Apr 30 03:31 covid19_confirmed_global.csv
# drwxr-xr-x 1 root root  4096 Apr  3 16:24 sample_data

# %% [markdown]
# Next, import the libraries we will use for processing and plotting the data:

# %%
import matplotlib.pyplot as plt
import matplotlib
matplotlib.rcParams['figure.figsize'] = [30, 15]
import numpy as np
import pandas as pd

# %% [markdown]
# Load the downloaded dataset (csv file) into a Pandas dataframe and remove some columns we will not use:

# %%
confirmed_df = pd.read_csv('covid19_confirmed_global.csv', sep=',', header=0, error_bad_lines=False)
confirmed_df = confirmed_df.drop(['Lat', 'Long', 'Province/State'], axis=1)
confirmed_df
# Out:
#             Country/Region  1/22/20  1/23/20  ...  4/27/20  4/28/20  4/29/20
# 0              Afghanistan        0        0  ...     1703     1828     1939
# 1                  Albania        0        0  ...      736      750      766
# 2                  Algeria        0        0  ...     3517     3649     3848
# 3                  Andorra        0        0  ...      743      743      743
# 4                   Angola        0        0  ...       27       27       27
# ..                     ...      ...      ...  ...      ...      ...      ...
# 259                 France        0        0  ...        1        1        1
# 260            South Sudan        0        0  ...        6       34       34
# 261         Western Sahara        0        0  ...        6        6        6
# 262  Sao Tome and Principe        0        0  ...        4        8        8
# 263                  Yemen        0        0  ...        1        1        6
#
# [264 rows x 100 columns]

# %% [markdown]
# Create a new dataframe with just the countries that we want to look at:

# %%
selected_countries_df = confirmed_df.loc[(confirmed_df['Country/Region'] == 'Argentina') | (confirmed_df['Country/Region'] == 'Spain') | (confirmed_df['Country/Region'] == 'Italy') | (confirmed_df['Country/Region'] == 'Germany')]
selected_countries_df = selected_countries_df.set_index('Country/Region')
selected_countries_df
# Out:
#                 1/22/20  1/23/20  1/24/20  ...  4/27/20  4/28/20  4/29/20
# Country/Region                             ...
# Argentina             0        0        0  ...     4003     4127     4285
# Germany               0        0        0  ...   158758   159912   161539
# Italy                 0        0        0  ...   199414   201505   203591
# Spain                 0        0        0  ...   229422   232128   236899
#
# [4 rows x 99 columns]

# %% [markdown]
# Check how many columns with data we got:

# %%
num_cols_all = selected_countries_df.count(axis='columns')
cols = num_cols_all['Argentina']
cols
# Out:
# 99

# %% [markdown]
# Shift some of the rows so we can better compare the growth of the curves. The idea is to shift the rows so that the day of the first reported virus case is aligned for the different countries (due to shifting the values, the dates will no longer match. We will replace them with number of days in one of the following steps):

# %%
shifted_df = selected_countries_df.copy()
shifted_df.loc['Argentina'] = shifted_df.loc['Argentina'].shift(-36)
shifted_df.loc['Italy'] = shifted_df.loc['Italy'].shift(-4)
shifted_df.loc['Spain'] = shifted_df.loc['Spain'].shift(-5)
shifted_df
# Out:
#                 1/22/20  1/23/20  1/24/20  ...   4/27/20   4/28/20   4/29/20
# Country/Region                             ...
# Argentina           0.0      0.0      0.0  ...       NaN       NaN       NaN
# Germany             0.0      0.0      0.0  ...  158758.0  159912.0  161539.0
# Italy               0.0      0.0      0.0  ...       NaN       NaN       NaN
# Spain               0.0      0.0      0.0  ...       NaN       NaN       NaN
#
# [4 rows x 99 columns]

# %% [markdown]
# Remove the first columns with zero values and also the columns to the right,  that do not have values for all countries:

# %%
# remove the first 5 columns with zero values 
first_empty_columns = 5
shifted_df = shifted_df.iloc[:, first_empty_columns:cols-36]
# remove the dates with number of days, as dates longer match
shifted_df.columns = range(cols-36-first_empty_columns)
shifted_df
# Out:
#                  0    1    2    3   ...       54       55       56       57
# Country/Region                      ...
# Argentina       1.0  1.0  1.0  2.0  ...   3892.0   4003.0   4127.0   4285.0
# Germany         1.0  4.0  4.0  4.0  ...  22213.0  24873.0  29056.0  32986.0
# Italy           2.0  2.0  2.0  2.0  ...  74386.0  80589.0  86498.0  92472.0
# Spain           1.0  1.0  1.0  1.0  ...  57786.0  65719.0  73235.0  80110.0
#
# [4 rows x 58 columns]

# %% [markdown]
# Transpose the dataframe (switch rows with columns) so we a column for each country:

# %%
shifted_df = shifted_df.transpose()
shifted_df
# Out:
# Country/Region  Argentina  Germany    Italy    Spain
# 0                     1.0      1.0      2.0      1.0
# 1                     1.0      4.0      2.0      1.0
# 2                     1.0      4.0      2.0      1.0
# 3                     2.0      4.0      2.0      1.0
# 4                     8.0      5.0      2.0      1.0
# 5                    12.0      8.0      2.0      1.0
# 6                    12.0     10.0      2.0      1.0
# 7                    17.0     12.0      3.0      1.0
# 8                    19.0     12.0      3.0      2.0
# 9                    19.0     12.0      3.0      2.0
# 10                   31.0     12.0      3.0      2.0
# 11                   34.0     13.0      3.0      2.0
# 12                   45.0     13.0      3.0      2.0
# 13                   56.0     14.0      3.0      2.0
# 14                   68.0     14.0      3.0      2.0
# 15                   79.0     16.0      3.0      2.0
# 16                   97.0     16.0      3.0      2.0
# 17                  128.0     16.0      3.0      2.0
# 18                  158.0     16.0      3.0      2.0
# 19                  266.0     16.0      3.0      2.0
# 20                  301.0     16.0      3.0      2.0
# 21                  387.0     16.0     20.0      2.0
# 22                  387.0     16.0     62.0      2.0
# 23                  502.0     16.0    155.0      2.0
# 24                  589.0     16.0    229.0      6.0
# 25                  690.0     16.0    322.0     13.0
# 26                  745.0     16.0    453.0     15.0
# 27                  820.0     16.0    655.0     32.0
# 28                 1054.0     16.0    888.0     45.0
# 29                 1054.0     17.0   1128.0     84.0
# 30                 1133.0     27.0   1694.0    120.0
# 31                 1265.0     46.0   2036.0    165.0
# 32                 1451.0     48.0   2502.0    222.0
# 33                 1451.0     79.0   3089.0    259.0
# 34                 1554.0    130.0   3858.0    400.0
# 35                 1628.0    159.0   4636.0    500.0
# 36                 1715.0    196.0   5883.0    673.0
# 37                 1795.0    262.0   7375.0   1073.0
# 38                 1975.0    482.0   9172.0   1695.0
# 39                 1975.0    670.0  10149.0   2277.0
# 40                 2142.0    799.0  12462.0   2277.0
# 41                 2208.0   1040.0  12462.0   5232.0
# 42                 2277.0   1176.0  17660.0   6391.0
# 43                 2443.0   1457.0  21157.0   7798.0
# 44                 2571.0   1908.0  24747.0   9942.0
# 45                 2669.0   2078.0  27980.0  11748.0
# 46                 2758.0   3675.0  31506.0  13910.0
# 47                 2839.0   4585.0  35713.0  17963.0
# 48                 2941.0   5795.0  41035.0  20410.0
# 49                 3031.0   7272.0  47021.0  25374.0
# 50                 3144.0   9257.0  53578.0  28768.0
# 51                 3435.0  12327.0  59138.0  35136.0
# 52                 3607.0  15320.0  63927.0  39885.0
# 53                 3780.0  19848.0  69176.0  49515.0
# 54                 3892.0  22213.0  74386.0  57786.0
# 55                 4003.0  24873.0  80589.0  65719.0
# 56                 4127.0  29056.0  86498.0  73235.0
# 57                 4285.0  32986.0  92472.0  80110.0

# %% [markdown]
# ## Plot the curve (Y axis has logarithmic scale):

# %%
shifted_df.plot(kind='line', title='Curves synced when first case was reported. Y axis has logarithmic scale.', logy=True)

# %% [markdown]
# Now plot the same curves but shift them so they align where each country reaches a minimum of 45 cases:

# %%
def get_shifted_curves(df, columns, shift_values, remove_first_x):
    min_shift = 0
    shifted_df = df.copy()
    for country in shift_values:
        min_shift = min(min_shift, shift_values[country])
        shifted_df.loc[country] = shifted_df.loc[country].shift(shift_values[country])    

    # remove the first x columns with zero values 
    shifted_df = shifted_df.iloc[:, remove_first_x:columns + min_shift]
    # remove the dates with number of days, as dates longer match
    shifted_df.columns = range(columns + min_shift - remove_first_x)
    shifted_df = shifted_df.transpose()
    return shifted_df

# %%
shifts = {'Argentina': -17, 'Spain': -2, 'Italy': 5}
first_empty_rows = 25

shifted_45_cases_df = get_shifted_curves(selected_countries_df, cols, shifts, first_empty_rows)
shifted_45_cases_df
# Out:
# Country/Region  Argentina   Germany     Italy     Spain
# 0                     1.0      16.0       3.0       2.0
# 1                     1.0      16.0       3.0       2.0
# 2                     2.0      16.0       3.0       2.0
# 3                     8.0      16.0       3.0       2.0
# 4                    12.0      16.0       3.0       2.0
# 5                    12.0      16.0       3.0       2.0
# 6                    17.0      16.0       3.0       2.0
# 7                    19.0      16.0       3.0       6.0
# 8                    19.0      16.0       3.0      13.0
# 9                    31.0      17.0       3.0      15.0
# 10                   34.0      27.0      20.0      32.0
# 11                   45.0      46.0      62.0      45.0
# 12                   56.0      48.0     155.0      84.0
# 13                   68.0      79.0     229.0     120.0
# 14                   79.0     130.0     322.0     165.0
# 15                   97.0     159.0     453.0     222.0
# 16                  128.0     196.0     655.0     259.0
# 17                  158.0     262.0     888.0     400.0
# 18                  266.0     482.0    1128.0     500.0
# 19                  301.0     670.0    1694.0     673.0
# 20                  387.0     799.0    2036.0    1073.0
# 21                  387.0    1040.0    2502.0    1695.0
# 22                  502.0    1176.0    3089.0    2277.0
# 23                  589.0    1457.0    3858.0    2277.0
# 24                  690.0    1908.0    4636.0    5232.0
# 25                  745.0    2078.0    5883.0    6391.0
# 26                  820.0    3675.0    7375.0    7798.0
# 27                 1054.0    4585.0    9172.0    9942.0
# 28                 1054.0    5795.0   10149.0   11748.0
# 29                 1133.0    7272.0   12462.0   13910.0
# 30                 1265.0    9257.0   12462.0   17963.0
# 31                 1451.0   12327.0   17660.0   20410.0
# 32                 1451.0   15320.0   21157.0   25374.0
# 33                 1554.0   19848.0   24747.0   28768.0
# 34                 1628.0   22213.0   27980.0   35136.0
# 35                 1715.0   24873.0   31506.0   39885.0
# 36                 1795.0   29056.0   35713.0   49515.0
# 37                 1975.0   32986.0   41035.0   57786.0
# 38                 1975.0   37323.0   47021.0   65719.0
# 39                 2142.0   43938.0   53578.0   73235.0
# 40                 2208.0   50871.0   59138.0   80110.0
# 41                 2277.0   57695.0   63927.0   87956.0
# 42                 2443.0   62095.0   69176.0   95923.0
# 43                 2571.0   66885.0   74386.0  104118.0
# 44                 2669.0   71808.0   80589.0  112065.0
# 45                 2758.0   77872.0   86498.0  119199.0
# 46                 2839.0   84794.0   92472.0  126168.0
# 47                 2941.0   91159.0   97689.0  131646.0
# 48                 3031.0   96092.0  101739.0  136675.0
# 49                 3144.0  100123.0  105792.0  141942.0
# 50                 3435.0  103374.0  110574.0  148220.0
# 51                 3607.0  107663.0  115242.0  153222.0
# 52                 3780.0  113296.0  119827.0  158273.0
# 53                 3892.0  118181.0  124632.0  163027.0
# 54                 4003.0  122171.0  128948.0  166831.0
# 55                 4127.0  124908.0  132547.0  170099.0
# 56                 4285.0  127854.0  135586.0  172541.0

# %% [markdown]
# ## Plot the curves aligned where each country has more than 45 reported cases (Y axis has logarithmic scale):

# %%
shifted_45_cases_df.plot(kind='line', title='Sync the curves at more than 45 cases reported. Y axis has logarithmic scale', logy=True)

# %% [markdown]
# Now do the same but align the curves where more than 100 cases were reported:

# %%
shifts = {'Argentina': -19, 'Spain': -1, 'Italy': 7}
first_empty_rows = 22

shifted_100_cases_df = get_shifted_curves(selected_countries_df, cols, shifts, first_empty_rows)
shifted_100_cases_df
# Out:
# Country/Region  Argentina   Germany     Italy     Spain
# 0                     1.0      16.0       2.0       2.0
# 1                     1.0      16.0       3.0       2.0
# 2                     1.0      16.0       3.0       2.0
# 3                     2.0      16.0       3.0       2.0
# 4                     8.0      16.0       3.0       2.0
# 5                    12.0      16.0       3.0       2.0
# 6                    12.0      16.0       3.0       2.0
# 7                    17.0      16.0       3.0       2.0
# 8                    19.0      16.0       3.0       2.0
# 9                    19.0      16.0       3.0       2.0
# 10                   31.0      16.0       3.0       2.0
# 11                   34.0      16.0       3.0       6.0
# 12                   45.0      17.0       3.0      13.0
# 13                   56.0      27.0       3.0      15.0
# 14                   68.0      46.0       3.0      32.0
# 15                   79.0      48.0      20.0      45.0
# 16                   97.0      79.0      62.0      84.0
# 17                  128.0     130.0     155.0     120.0
# 18                  158.0     159.0     229.0     165.0
# 19                  266.0     196.0     322.0     222.0
# 20                  301.0     262.0     453.0     259.0
# 21                  387.0     482.0     655.0     400.0
# 22                  387.0     670.0     888.0     500.0
# 23                  502.0     799.0    1128.0     673.0
# 24                  589.0    1040.0    1694.0    1073.0
# 25                  690.0    1176.0    2036.0    1695.0
# 26                  745.0    1457.0    2502.0    2277.0
# 27                  820.0    1908.0    3089.0    2277.0
# 28                 1054.0    2078.0    3858.0    5232.0
# 29                 1054.0    3675.0    4636.0    6391.0
# 30                 1133.0    4585.0    5883.0    7798.0
# 31                 1265.0    5795.0    7375.0    9942.0
# 32                 1451.0    7272.0    9172.0   11748.0
# 33                 1451.0    9257.0   10149.0   13910.0
# 34                 1554.0   12327.0   12462.0   17963.0
# 35                 1628.0   15320.0   12462.0   20410.0
# 36                 1715.0   19848.0   17660.0   25374.0
# 37                 1795.0   22213.0   21157.0   28768.0
# 38                 1975.0   24873.0   24747.0   35136.0
# 39                 1975.0   29056.0   27980.0   39885.0
# 40                 2142.0   32986.0   31506.0   49515.0
# 41                 2208.0   37323.0   35713.0   57786.0
# 42                 2277.0   43938.0   41035.0   65719.0
# 43                 2443.0   50871.0   47021.0   73235.0
# 44                 2571.0   57695.0   53578.0   80110.0
# 45                 2669.0   62095.0   59138.0   87956.0
# 46                 2758.0   66885.0   63927.0   95923.0
# 47                 2839.0   71808.0   69176.0  104118.0
# 48                 2941.0   77872.0   74386.0  112065.0
# 49                 3031.0   84794.0   80589.0  119199.0
# 50                 3144.0   91159.0   86498.0  126168.0
# 51                 3435.0   96092.0   92472.0  131646.0
# 52                 3607.0  100123.0   97689.0  136675.0
# 53                 3780.0  103374.0  101739.0  141942.0
# 54                 3892.0  107663.0  105792.0  148220.0
# 55                 4003.0  113296.0  110574.0  153222.0
# 56                 4127.0  118181.0  115242.0  158273.0
# 57                 4285.0  122171.0  119827.0  163027.0

# %% [markdown]
# ## Plot the curves aligned where each country has more than 100 reported cases (Y axis has logarithmic scale):

# %%
shifted_100_cases_df.plot(kind='line', title='Start of curce at more than 100 cases - Y axis has logarithmic scale', logy=True)
